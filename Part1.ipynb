# %%
import pandas as pd

# %% [markdown]
# Read data

# %%
#read csv file
df1 = pd.read_csv("sales_data_sample.csv", encoding="latin1")
display(df1.head(3))

# read excel file
df2 = pd.read_excel("SampleSuperstore.xlsx")
display(df2.head(3))

#read json file
df3 = pd.read_json("sample_Data.json")
display(df3.head(3))
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
#
#         ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0  2/24/2003 0:00  Shipped       1         2     2003  ...
# 1   5/7/2003 0:00  Shipped       2         5     2003  ...
# 2   7/1/2003 0:00  Shipped       3         7     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2   CITY STATE POSTALCODE  \
# 0        897 Long Airport Avenue           NaN    NYC    NY      10022
# 1             59 rue de l'Abbaye           NaN  Reims   NaN      51100
# 2  27 rue du Colonel Pierre Avia           NaN  Paris   NaN      75508
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0     USA       NaN              Yu             Kwai    Small
# ...

# %% [markdown]
# Save data csv, xlxs, json format

# %%
sample_data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "Los Angeles", "Chicago"]
}
sample_df = pd.DataFrame(sample_data)
# Save DataFrame to CSV
sample_df.to_csv("sample_data.csv", index=False)

# Save DataFrame to Excel
sample_df.to_excel("sample_data.xlsx", index=False)

# Save DataFrame to JSON
sample_df.to_json("sample_data.json")

# %% [markdown]
# Dataset Info

# %%
print(df1.info())
print(df2.info())
print(df3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# Descriptive Statistics for numerical columns of a DataSet

# %%
import pandas as pd
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Hannah"],
    "Age": [25, 30, 35, 40, 28, 33, 45, 29],
    "Salary": [50000, 60000, 70000, 80000, 55000, 65000, 90000, 62000],
    "Ratings": [4.5, 3.8, 4.2, 4.9, 3.5, 4.0, 4.8, 3.9]
}
print(data_frame)
data_frame = pd.DataFrame(data)
print("Descriptive statistics:\n", data_frame.describe())
# Out:
#       Name  Age  Salary  Ratings
# 0    Alice   25   50000      4.5
# 1      Bob   30   60000      3.8
# 2  Charlie   35   70000      4.2
# 3    David   40   80000      4.9
# 4      Eve   28   55000      3.5
# 5    Frank   33   65000      4.0
# 6    Grace   45   90000      4.8
# 7   Hannah   29   62000      3.9
# Descriptive statistics:
#               Age        Salary   Ratings
# count   8.000000      8.000000  8.000000
# mean   33.125000  66500.000000  4.200000
# std     6.664136  13180.071537  0.495696
# min    25.000000  50000.000000  3.500000
# 25%    28.750000  58750.000000  3.875000
# 50%    31.500000  63500.000000  4.100000
# 75%    36.250000  72500.000000  4.575000
# max    45.000000  90000.000000  4.900000

# %% [markdown]
# Shape and Columns of DataSet

# %%
print(f"Shape: {data_frame.shape}")
print(f"Columns: {data_frame.columns}")
# Out:
# Shape: (8, 4)
# Columns: Index(['Name', 'Age', 'Salary', 'Ratings'], dtype='object')

# %% [markdown]
# Selecting columns from DataFrame

# %%
#single column selection
single_column = data_frame["Name"]
print("Single Column Selection:\n", single_column)

#multiple column selection
multiple_columns = data_frame[["Name", "Age"]]
print("Multiple Column Selection:\n", multiple_columns)
# Out:
# Single Column Selection:
#  0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# 5      Frank
# 6      Grace
# 7     Hannah
# Name: Name, dtype: object
# Multiple Column Selection:
#        Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
# 4      Eve   28
# 5    Frank   33
# 6    Grace   45
# 7   Hannah   29

# %% [markdown]
# Row selections

# %%
# single row selection
single_row = data_frame.iloc[2]  # Selects the third row (index 2)
print("Single Row Selection:\n", single_row)

print("-" * 50)

# multiple row selection
multiple_rows = data_frame.iloc[1:4]  # Selects rows from index 1 to 3
print("Multiple Row Selection:\n", multiple_rows)
# Out:
# Single Row Selection:
#  Name       Charlie
# Age             35
# Salary       70000
# Ratings        4.2
# Name: 2, dtype: object
# --------------------------------------------------
# Multiple Row Selection:
#        Name  Age  Salary  Ratings
# 1      Bob   30   60000      3.8
# 2  Charlie   35   70000      4.2
# 3    David   40   80000      4.9

# %% [markdown]
# Filtering rows using sinle and multiple conditions

# %%
# single condition filtering
filtered_single_condition = data_frame[data_frame["Age"] > 30]
print("Filtered Rows (Age > 30):\n", filtered_single_condition)

print("-" * 50)

# multiple conditions filtering
filtered_multiple_conditions = data_frame[(data_frame["Age"] > 30) & (data_frame["Salary"] > 60000)]
print("Filtered Rows (Age > 30 and Salary > 60000):\n", filtered_multiple_conditions)
# Out:
# Filtered Rows (Age > 30):
#        Name  Age  Salary  Ratings
# 2  Charlie   35   70000      4.2
# 3    David   40   80000      4.9
# 5    Frank   33   65000      4.0
# 6    Grace   45   90000      4.8
# --------------------------------------------------
# Filtered Rows (Age > 30 and Salary > 60000):
#        Name  Age  Salary  Ratings
# 2  Charlie   35   70000      4.2
# 3    David   40   80000      4.9
# 5    Frank   33   65000      4.0
# 6    Grace   45   90000      4.8
